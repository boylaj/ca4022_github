# %%
import pandas as pd

# %%
genreBreakdown = pd.read_csv(
    "/home/jack/Desktop/ca4022/output/hive_analysis/genreBreakdown/genreBreakdown.csv",
    sep = "\t",
    names=["genre", "numMoviesInGenre", "AvgGenreRating", "RatingsCount"]
)
genreBreakdown.head()
# Out:
#        genre  numMoviesInGenre  AvgGenreRating  RatingsCount
# 0  Adventure              1262        3.215230         24161
# 1  Animation               610        3.497119          6988
# 2   Children               664        3.107690          9208
# 3     Comedy              3753        3.181716         39053
# 4    Fantasy               778        3.218843         11834

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()


sns.catplot(
    data=genreBreakdown,
    x="RatingsCount",
    y="genre",
    kind="bar",
    height=15
)

# %%
sns.catplot(
    data=genreBreakdown,
    x="AvgGenreRating",
    y="genre",
    kind="bar",
    height=15,
)

# %%
#the movies with more than 50% 5stars in order of most 5star ratings
majorityFiveStars = pd.read_csv(
    "/home/jack/Desktop/ca4022/output/hive_analysis/majorityFiveStars/majorityFiveStars.csv",
    sep = "\t",
    names = ["title", "5stars", "4stars", "3stars", "2stars", "1stars", "totalRatings"]
)
majorityFiveStars
# Out:
#                                       title  5stars  4stars  3stars  2stars  \
# 0                 Shawshank Redemption, The     202      87      24       2
# 1                              Pulp Fiction     167      89      34       9
# 2                               Matrix, The     150      90      24       5
# 3        Star Wars: Episode IV - A New Hope     128      92      19      10
# 4                          Schindler's List     128      60      20       5
# ..                                      ...     ...     ...     ...     ...
# 127                          Temple Grandin       3       1       0       0
# 128                                 Lincoln       3       1       0       0
# 129    Louis C.K.: Live at The Comedy Store       3       0       1       0
# 130               Hunt for the Wilderpeople       3       1       0       0
# 131  Chungking Express (Chung Hing sam lam)       3       0       1       0
#
#      1stars  totalRatings
# 0         2           317
# 1         8           307
# 2         9           278
# 3         2           251
# 4         7           220
# ..      ...           ...
# 127       0             4
# 128       0             4
# 129       0             4
# 130       0             4
# 131       0             4
#
# [132 rows x 7 columns]

# %%
mostRatedMovies = pd.read_csv(
    "/home/jack/Desktop/ca4022/output/hive_analysis/mostRatedMovies/mostRatedMovies.csv",
    sep = "\t",
    names = ["title", "ratingCount", "avgRating", "genre"]
    
)
mostRatedMovies
# Out:
#                                                    title  \
# Forrest Gump                               329  4.164134
# Shawshank Redemption, The                  317  4.429022
# Pulp Fiction                               307  4.197068
# Silence of the Lambs, The                  279  4.161290
# Matrix, The                                278  4.192446
# ...                                                  ...
# 13 Tzameti                                 1    4.500000
# Return to Sender                           1    1.500000
# Shootist, The                              1    3.500000
# Dave Chappelle: Deep in the Heart of Texas 1    4.000000
# Elections Day                              1    4.500000
#
#                                                                   ratingCount  \
# Forrest Gump                               329     (Comedy,Drama,Romance,War)
# Shawshank Redemption, The                  317                  (Crime,Drama)
# Pulp Fiction                               307  (Comedy,Crime,Drama,Thriller)
# Silence of the Lambs, The                  279        (Crime,Horror,Thriller)
# Matrix, The                                278       (Action,Sci-Fi,Thriller)
# ...                                                                       ...
# 13 Tzameti                                 1             (Film-Noir,Thriller)
# Return to Sender                           1                       (Thriller)
# Shootist, The                              1                  (Drama,Western)
# Dave Chappelle: Deep in the Heart of Texas 1                         (Comedy)
# Elections Day                              1                         (Comedy)
#
#                                                 avgRating  genre
# Forrest Gump                               329        5.0    0.5
# Shawshank Redemption, The                  317        5.0    1.0
# Pulp Fiction                               307        5.0    0.5
# Silence of the Lambs, The                  279        5.0    0.5
# Matrix, The                                278        5.0    0.5
# ...                                                   ...    ...
# 13 Tzameti                                 1          4.5    4.5
# Return to Sender                           1          1.5    1.5
# Shootist, The                              1          3.5    3.5
# Dave Chappelle: Deep in the Heart of Texas 1          4.0    4.0
# Elections Day                              1          4.5    4.5
#
# [9724 rows x 4 columns]

# %%
sns.catplot(
    data=mostRatedMovies.head(),
    y="ratingCount",
    x="title",
    kind="bar",
    height=15
)

# %%
nicestUsers = pd.read_csv(
    "/home/jack/Desktop/ca4022/output/hive_analysis/nicestUsers/nicestUsers.csv",
    sep = "\t",
    names = ["userID", "numRatings", "avgRating"]
)
nicestUsers
# Out:
#     userID  numRatings           avgRating
# 0       53          20                 5.0
# 1      251          23   4.869565217391305
# 2      515          26   4.846153846153846
# 3       25          26  4.8076923076923075
# 4       30          34   4.735294117647059
# ..     ...         ...                 ...
# 606    153         179   2.217877094972067
# 607    508          24  2.1458333333333335
# 608    139         194  2.1443298969072164
# 609    442          20               1.275
# 610     \N           0                  \N
#
# [611 rows x 3 columns]

# %%
totalRatings = pd.read_csv(
    "/home/jack/Desktop/ca4022/output/hive_analysis/totalRatings/totalRatings.csv",
    sep = "\t",
    names = ["5star", "4star", "3star", "2star", "1star"]
)
totalRatings
# Out:
#    5star  4star  3star  2star  1star
# 0  21762  39954  25597   9342   4181

# %%
movies = pd.read_csv(
    "/home/jack/Desktop/ca4022/output/movies.csv",
    sep = "\t"
)
movies.head()
# Out:
#    movieID                        title    year  \
# 0        1                    Toy Story  1995.0
# 1        2                      Jumanji  1995.0
# 2        3             Grumpier Old Men  1995.0
# 3        4            Waiting to Exhale  1995.0
# 4        5  Father of the Bride Part II  1995.0
#
#                                            genre
# 0  (Adventure,Animation,Children,Comedy,Fantasy)
# 1                   (Adventure,Children,Fantasy)
# 2                               (Comedy,Romance)
# 3                         (Comedy,Drama,Romance)
# 4                                       (Comedy)
